# %% [markdown]
# <a href="https://colab.research.google.com/github/Victorrani/applied-programming-exercises/blob/main/PA_sinotica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Criação de um climograma para a cidade de Porto Alegre, Brasil
# Seria necessária a utilização de outra biblioteca que não estava funcionando. Decidi então, criar o próprio dataFrame utilizando os dados da normal climatológica 1991-2020 do INMET
# https://portal.inmet.gov.br/normais
# Foram selecionadas as variáveis, Precpitação mensal, temperatura máxima, média e mínima.
# Utilizadas as bilbiotecas:
# Pandas - criação do DataFrame (de uma planilha de excell)
# Matplotlib - criação do plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
arquivo = 'Planilha sem título (1).xlsx'

df = pd.read_excel(arquivo)
df.head()
# Out:
#   Unnamed: 0  Precptação mensal  Temp max  Temp mean  Temp min
# 0        Jan              120.7      31.0       25.0      20.7
# 1        Fev              110.8      30.5       24.7      20.7
# 2        Mar              103.3      29.2       23.5      19.5
# 3        Abr              114.4      26.4       20.7      16.8
# 4        Mai              112.8      22.6       17.2      13.6

# %%
fig, ax1 = plt.subplots()

##criação dos plots com o eixo x compartilhado e 2 eixos y

ax2 = ax1.twinx()

##criando a escala para o eixo y dos gráficos ax1 e ax2
##ax1 precpitação, ax2 temperaturas
ax1.set_ylim([0, 200])
ax2.set_ylim([0, 40])
ax1.set_ylabel('Precipitação (mm)', color='black')
ax2.set_ylabel('Temperatura (°C)', color='black')

##plot dos gráficos, ax1 e barras, ax2 em linha

img1 = ax1.bar(df['Unnamed: 0'] ,df['Precipitação mensal'], label='Precipitação (mm)')
img2 = ax2.plot(df['Unnamed: 0'] ,df['Temp max'], color='red', label='Temp Max (°C)')
img3 = ax2.plot(df['Unnamed: 0'] ,df['Temp mean'], color='yellow', label='Temp Mean (°C)')
img4 = ax2.plot(df['Unnamed: 0'] ,df['Temp min'], color='black', label='Temp Min (°C)')

## título do gráfico e legendas
plt.suptitle("Climograma Porto Alegre 1991-2020")
plt.legend()
ax1.set_label('Precipitação (mm)')
plt.show()
